# %%
import pandas as pd

# %%
pd.read_csv('results/leaderboard.csv').sort_values(by='Average WER', ascending=True)
# Out:
#                                 Model  SADA WER  SADA CER  \
# 11       KFUPM-JRCAI/WhisperArabic_v5     52.59     25.91
# 8             facebook/omniASR-LLM-1B     59.48     31.69
# 10       KFUPM-JRCAI/WhisperArabic_v4     50.97     24.70
# 12       KFUPM-JRCAI/WhisperArabic_v7     51.19     25.20
# 1     Systran/faster-whisper-large-v3     55.39     34.44
# 9        KFUPM-JRCAI/WhisperArabic_v3     56.57     30.81
# 7   KFUPM-JRCAI/WhisperTurboArabic_v2     58.84     27.57
# 4                 Qwen/Qwen3-ASR-1.7B     52.05     26.67
# 6      KFUPM-JRCAI/WhisperTurboArabic     66.38     33.80
# 0                            arabicai     68.00     37.23
# 3                           canary-1b     63.79     33.38
# 2     parakeet-1-1b-rnnt-multilingual     71.98     52.47
# 5      KFUPM-JRCAI/WhisperLargeArabic     95.26     59.45
#
#     Common Voice 18.0 WER  Common Voice 18.0 CER  MASC (Clean) WER  \
# 11                   9.31                   2.54             34.52
# ...
