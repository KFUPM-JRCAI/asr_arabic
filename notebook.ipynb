# %%
import pandas as pd

# %%
pd.read_csv('results/leaderboard.csv')
# Out:
#                              Model  SADA WER  SADA CER  Common Voice 18.0 WER  \
# 0  Systran/faster-whisper-large-v3     55.39     34.44                  10.86
#
#    Common Voice 18.0 CER  MASC (Clean) WER  MASC (Clean) CER  \
# 0                   2.98             35.21              8.65
#
#    MASC (Noisy) WER  MASC (Noisy) CER  MGB-2 WER  MGB-2 CER  Casablanca WER  \
# 0             40.64             13.71      32.87      14.98           66.51
#
#    Casablanca CER  Average WER  Average CER
# 0            31.2        40.25        17.66
