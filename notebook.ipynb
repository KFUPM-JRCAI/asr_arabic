# %%
import pandas as pd

# %%
pd.read_csv('results/leaderboard.csv')
# Out:
#                              Model  SADA WER  SADA CER  Common Voice 18.0 WER  \
# 0                         arabicai     68.00     37.23                  13.08
# 1  Systran/faster-whisper-large-v3     55.39     34.44                  10.86
# 2  parakeet-1-1b-rnnt-multilingual     71.98     52.47                  12.20
# 3                        canary-1b     63.79     33.38                  14.19
#
#    Common Voice 18.0 CER  MASC (Clean) WER  MASC (Clean) CER  \
# 0                   4.27             36.58              9.85
# 1                   2.98             35.21              8.65
# 2                   5.70             41.51             16.94
# 3                   4.36             37.26              9.85
#
#    MASC (Noisy) WER  MASC (Noisy) CER  MGB-2 WER  MGB-2 CER  Casablanca WER  \
# 0             43.72             14.41      36.92      16.09           71.24
# 1             40.64             13.71      32.87      14.98           66.51
# ...
